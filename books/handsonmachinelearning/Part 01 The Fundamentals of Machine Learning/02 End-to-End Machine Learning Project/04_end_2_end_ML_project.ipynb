# %% [markdown]
# # End-to-end Machine Learning Project
#
# ## Explore and Visualize the Data to Gain Insights
#
# - The goal is to go into the data a little more depth.

# %%
from pathlib import Path
import pandas as pd
import tarfile
import urllib.request
import matplotlib.pyplot as plt
import numpy as np
from zlib import crc32
from sklearn.model_selection import train_test_split

# %%
# previus neccessary code
housing = pd.read_csv("./datasets/housing/housing.csv")
housing["income_cat"] = pd.cut(
    housing["median_income"],
    bins=[0., 1.5, 3.0, 4.5, 6., np.inf],
    labels=[1, 2, 3, 4, 5]
)
strat_train_set, strat_test_set = train_test_split(
    housing, 
    test_size=0.2,
    stratify=housing["income_cat"],
    random_state=42
)
for set_ in (strat_train_set, strat_test_set):
    set_.drop("income_cat", axis=1, inplace=True)

# %% [markdown]
# - Because we are going to experiment, we should make a copy of the original

# %%
housing = strat_train_set.copy()

# %% [markdown]
# ### Visualizating Geographical Data

# %% [markdown]
# - Create a scatterplot of all the districts to visualize the data

# %%
housing.plot(
    kind="scatter",
    x="longitude",
    y="latitude",
    grid=True
)
plt.show()

# %% [markdown]
# - Looks like California, hard to see a pattern
# - Let's add some alpha blending to see the density of data points

# %%
housing.plot(
    kind="scatter",
    x="longitude",
    y="latitude",
    grid=True,
    alpha=0.2
)
plt.show()

# %% [markdown]
# - By setting the alpha option to 0.2, you make the data points transparent. This allows overlapping points to accumulate color intensity, effectively highlighting high-density areas as darker regions, while low-density areas remain faint.
