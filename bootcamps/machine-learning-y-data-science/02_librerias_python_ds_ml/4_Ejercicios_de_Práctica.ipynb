# %% [markdown]
# # Ejercicios de Práctica - NumPy, Pandas y Matplotlib
#
# Este notebook contiene ejercicios prácticos para repasar las librerías fundamentales de Data Science en Python.
#
# **Instrucciones:** Resuelve cada ejercicio en la celda correspondiente. ¡Buena suerte!

# %% [markdown]
# ## Sección 1: NumPy
#
# ### Ejercicio 1.1: Creación y Manipulación de Arrays
#
# 1. Crea un array de NumPy con los números del 1 al 20
# 2. Reshape el array a una matriz de 4x5
# 3. Calcula la suma de cada fila
# 4. Calcula el promedio de cada columna

# %%
import numpy as np

# Tu código aquí

# %% [markdown]
# ### Ejercicio 1.2: Operaciones Matemáticas
#
# 1. Crea dos arrays aleatorios de 10 elementos cada uno (valores entre 0 y 100)
# 2. Realiza las siguientes operaciones:
#    - Suma de ambos arrays
#    - Producto elemento por elemento
#    - Encuentra el valor máximo y mínimo de cada array
#    - Calcula la desviación estándar de cada array

# %%
# Tu código aquí

# %% [markdown]
# ### Ejercicio 1.3: Indexación y Slicing
#
# 1. Crea una matriz de 6x6 con números aleatorios entre 1 y 50
# 2. Extrae la submatriz central de 4x4
# 3. Selecciona todos los elementos mayores a 25
# 4. Reemplaza todos los elementos menores a 15 por 0

# %%
# Tu código aquí

# %% [markdown]
# ### Ejercicio 1.4: Funciones Estadísticas
#
# 1. Crea un array con 100 números aleatorios que sigan una distribución normal (media=50, desviación estándar=10)
# 2. Calcula:
#    - Media
#    - Mediana
#    - Percentil 25 y 75
#    - Varianza
# 3. Encuentra cuántos valores están entre 40 y 60

# %%
# Tu código aquí

# %% [markdown]
# ## Sección 2: Pandas
#
# ### Ejercicio 2.1: Creación de DataFrames
#
# 1. Crea un DataFrame con las siguientes columnas:
#    - Nombre: ['Ana', 'Juan', 'María', 'Pedro', 'Laura', 'Carlos', 'Sofía', 'Diego']
#    - Edad: [25, 30, 28, 35, 22, 40, 27, 33]
#    - Ciudad: ['Madrid', 'Barcelona', 'Madrid', 'Valencia', 'Barcelona', 'Madrid', 'Valencia', 'Barcelona']
#    - Salario: [30000, 45000, 35000, 50000, 28000, 60000, 32000, 48000]
# 2. Muestra las primeras 3 filas
# 3. Muestra información general del DataFrame (info())
# 4. Muestra estadísticas descriptivas (describe())

# %%
import pandas as pd

# Tu código aquí

# %% [markdown]
# ### Ejercicio 2.2: Filtrado y Selección
#
# Usando el DataFrame del ejercicio anterior:
#
# 1. Selecciona solo las columnas 'Nombre' y 'Salario'
# 2. Filtra las personas que viven en Madrid
# 3. Filtra las personas mayores de 30 años con salario mayor a 40000
# 4. Selecciona las personas cuyo nombre empieza con 'M' o 'S'

# %%
# Tu código aquí

# %% [markdown]
# ### Ejercicio 2.3: Agrupación y Agregación
#
# Usando el DataFrame del ejercicio 2.1:
#
# 1. Agrupa por 'Ciudad' y calcula el salario promedio de cada ciudad
# 2. Agrupa por 'Ciudad' y cuenta cuántas personas hay en cada ciudad
# 3. Agrupa por 'Ciudad' y calcula la edad máxima y mínima de cada ciudad
# 4. Crea una columna nueva llamada 'Rango_Edad' que clasifique:
#    - 'Joven' si edad < 30
#    - 'Adulto' si edad >= 30

# %%
# Tu código aquí

# %% [markdown]
# ### Ejercicio 2.4: Limpieza de Datos
#
# 1. Crea un DataFrame con valores faltantes:
#    ```python
#    data = {
#        'A': [1, 2, np.nan, 4, 5],
#        'B': [np.nan, 2, 3, 4, 5],
#        'C': [1, 2, 3, np.nan, 5],
#        'D': [1, np.nan, np.nan, 4, 5]
#    }
#    ```
# 2. Identifica cuántos valores faltantes hay en cada columna
# 3. Rellena los valores faltantes de la columna 'A' con la media
# 4. Elimina las filas que tengan más de 1 valor faltante
# 5. Rellena los valores faltantes restantes con el método forward fill

# %%
# Tu código aquí

# %% [markdown]
# ### Ejercicio 2.5: Merge y Join
#
# 1. Crea dos DataFrames:
#    - df_empleados: con columnas ['ID', 'Nombre', 'Departamento_ID']
#    - df_departamentos: con columnas ['Departamento_ID', 'Nombre_Departamento', 'Presupuesto']
# 2. Realiza un merge para combinar ambos DataFrames
# 3. Calcula el presupuesto total por departamento

# %%
# Tu código aquí

# %% [markdown]
# ## Sección 3: Matplotlib
#
# ### Ejercicio 3.1: Gráfico de Líneas
#
# 1. Crea un array con valores de x de 0 a 10 (100 puntos)
# 2. Calcula y = sin(x) y y2 = cos(x)
# 3. Crea un gráfico de líneas que muestre ambas funciones
# 4. Añade:
#    - Título: "Funciones Trigonométricas"
#    - Etiquetas de ejes
#    - Leyenda
#    - Grid

# %%
import matplotlib.pyplot as plt

# Tu código aquí

# %% [markdown]
# ### Ejercicio 3.2: Gráfico de Barras
#
# 1. Usando el DataFrame del ejercicio 2.1, crea un gráfico de barras que muestre:
#    - El salario promedio por ciudad
# 2. Personaliza el gráfico con:
#    - Colores diferentes para cada barra
#    - Título y etiquetas de ejes
#    - Valores sobre cada barra

# %%
# Tu código aquí

# %% [markdown]
# ### Ejercicio 3.3: Histograma
#
# 1. Genera 1000 números aleatorios con distribución normal (media=100, std=15)
# 2. Crea un histograma con 30 bins
# 3. Añade una línea vertical en la media
# 4. Añade líneas verticales en media ± 1 desviación estándar (en color diferente)
# 5. Personaliza con título, etiquetas y leyenda

# %%
# Tu código aquí

# %% [markdown]
# ### Ejercicio 3.4: Scatter Plot
#
# 1. Genera datos aleatorios:
#    - x: 50 valores entre 0 y 100
#    - y: correlacionado con x con algo de ruido (y = 2*x + ruido)
# 2. Crea un scatter plot
# 3. Añade una línea de tendencia
# 4. Colorea los puntos según su valor de y (usa un colormap)
# 5. Añade una barra de color (colorbar)

# %%
# Tu código aquí

# %% [markdown]
# ### Ejercicio 3.5: Subplots
#
# 1. Crea una figura con 4 subplots (2x2)
# 2. En cada subplot muestra:
#    - Subplot 1: Gráfico de líneas (y = x²)
#    - Subplot 2: Gráfico de barras (ventas mensuales aleatorias)
#    - Subplot 3: Histograma (distribución normal)
#    - Subplot 4: Scatter plot (datos aleatorios)
# 3. Añade un título general a la figura
# 4. Ajusta el espaciado entre subplots

# %%
# Tu código aquí

# %% [markdown]
# ## Ejercicio Integrador
#
# ### Ejercicio 4: Análisis Completo de Datos
#
# 1. Crea un DataFrame con datos de ventas:
#    - 100 filas con columnas: ['Fecha', 'Producto', 'Cantidad', 'Precio_Unitario', 'Vendedor']
#    - Productos: ['A', 'B', 'C', 'D']
#    - Vendedores: ['Juan', 'María', 'Pedro']
#    - Fechas: últimos 30 días
#
# 2. Calcula:
#    - Total de ventas (Cantidad * Precio_Unitario)
#    - Ventas totales por producto
#    - Ventas totales por vendedor
#    - Producto más vendido
#    - Vendedor con mayores ventas
#
# 3. Visualiza:
#    - Gráfico de barras: Ventas por producto
#    - Gráfico de líneas: Evolución de ventas diarias
#    - Gráfico de pastel: Distribución de ventas por vendedor
#
# 4. Exporta:
#    - El DataFrame final a CSV
#    - Un resumen estadístico a un archivo de texto

# %%
# Tu código aquí

# %% [markdown]
# ## ¡Felicitaciones!
#
# Si has completado todos los ejercicios, has repasado exitosamente los conceptos fundamentales de NumPy, Pandas y Matplotlib.
#
# ### Próximos pasos:
# - Intenta resolver los ejercicios de diferentes maneras
# - Explora la documentación oficial de cada librería
# - Aplica estos conceptos a tus propios datasets
